# %% [markdown]
# <a href="https://colab.research.google.com/github/HJJJJX/Figure-Plotting/blob/main/Uncertainty_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12],
            [2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12],
            [2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12],
            [2, 4, 6, 12], [2, 4, 6, 12]]
y_values = [
    [19.7,10.2,6.9,3.0],[17.6,9.4,6.1,2.5],[18.8,10.7,6.7,3.0],
    [12.2,5.1,4.6,1.7],[10.5,4.9,3.3,1.3],[8.7,6.3,2.3,1.5],
    [6.7,5.9,2.2,0.8],[9.2,6.5,2.9,1.0],[5.2,4.3,4.4,1.7],
    [5.2,3.5,3.7,0.6],[3.6,2.3,3.1,1.0],
]

# Calculate 25th and 75th percentiles
percentile_25 = [
    [9.6,5.1,3.7,1.2],[7.9,4.8,3.5,1.2],[8.4,5.6,3.2,1.1],
    [-4.4,-0.7,-0.5,-0.6],[-6,0.9,-2.2,-0],[-8.2,-0.7,-3.4,-1.6],
    [-10.4,-3,-2.3,-2.3],[-10.5,-4.4,-0,-0.4],[-12.8,-7.2,-1.6,-2.4],
    [-13.5,-8.5,-4.1,-3.4],[-13.5,-10.9,-7.3,-0.3],
]
percentile_75 = [
    [31.4, 15.1,10.2,4.8],[27.4,14.2,9.3,3.9],[29.5,15.4,10.2,4.7],
    [28.3,11.2,8.9,4.2],[28.5,9.8,9.1,2.7],[27.8,11.6,8,3.9],
    [28.3,14.5,7.5,4.1],[28.9,16.0,5.7,2.5],[27.2,16.9,9.5,4.9],
    [28.4,16.1,10.3,5.1],[26,17.8,13.7,2.4],
]

# Create subplots
fig, axs = plt.subplots(4, 3, figsize=(15, 15))

# Titles for each subplot
titles = ["(a) 190 days", "(b) 180 days", "(c) 170 days",
          "(d) 100 days", "(e) 90 days", "(f) 80 days",
         "(g) 70 days", "(h) 60 days", "(i) 50 days",
         "(j) 45 days", "(k) 30 days"]

# Define common y-axis limits
ylim_min = 0
ylim_max = 2  # Adjust according to your data

# Plot data for each subplot
for j in range(4):
    for k in range(3):
        idx = j * 3 + k
        if idx == 11:  # Skip the last subplot
            continue
        ax = axs[j, k]
        ax.scatter(x_values[idx], (100 + np.array(y_values[idx]))/100, color="black")
        ax.set_xlabel("Survey Frequency, times/yr")
        ax.set_ylabel("Accuracy, %")
        ax.tick_params(axis="y")

        lns1 = ax.plot(x_values[idx], (100 + np.array(y_values[idx]))/100, linestyle="-", color="blue", label="Accuracy")

        # Add shadow region for lns1
        fill_between = ax.fill_between(
            x_values[idx],
            (100 + np.array(percentile_25[idx]))/100,
            (100 + np.array(percentile_75[idx]))/100,
            color="lightblue",
            alpha=0.3,
            label="IQR",
        )

        # Add red dashed line at y = 1.0
        ax.axhline(y=1.0, color='red', linestyle='--')

        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        ax.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12],
            [2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12],
            [2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12],
            [2, 4, 6, 12], [2, 4, 6, 12]]
y_values = [
    [10.5,4.9,3.3,1.8],[9.7,4.6,2.9,1.4],[10.5,4.9,3.5,1.8],
    [16.4,5.9,4.6,2.4],[17.2,4.4,5.6,1.4],[17.9,6.1,5.7,2.7],
    [18.9,8.7,5.0,3.2],[19.7,10.2,2.9,1.5],[19.5,12.1,5.5,3.5],
    [20.2,12.4,7.1,4.2],[19.3,14.2,10.6,1.4]
]



# Create subplots
fig, axs = plt.subplots(4, 3, figsize=(15, 15))

# Titles for each subplot
titles = ["(a) 190 days", "(b) 180 days", "(c) 170 days",
          "(d) 100 days", "(e) 90 days", "(f) 80 days",
         "(g) 70 days", "(h) 60 days", "(i) 50 days",
         "(j) 45 days", "(k) 30 days"]

# Define common y-axis limits
ylim_min = 0
ylim_max = 100  # Adjust according to your data

# Plot data for each subplot
for j in range(4):
    for k in range(3):
        idx = j * 3 + k
        if idx == 11:  # Skip the last subplot
            continue
        ax = axs[j, k]
        ax.scatter(x_values[idx], 100 - np.array(y_values[idx]), color="black")
        ax.set_xlabel("Survey Frequency, times/yr")
        ax.set_ylabel("Accuracy, %")
        ax.tick_params(axis="y")

        lns1 = ax.plot(x_values[idx], 100 - np.array(y_values[idx]), linestyle="-", color="blue", label="Precision")


        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        ax.legend(loc="lower right")

plt.tight_layout()
plt.show()

# %% [markdown]
# *   Repair

# %%
#Repair
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]
y_values = [[72.1,75.4,30.2,14.6,5.0], [41.6,46.7,50.3,26,4.5], [23.3,26.6,29.9,35.8,5.8], [-8.5,-4.5,-2.9,-1.8,11.4]]

# Calculate 25th and 75th percentiles
percentile_25 = [
    [55.9,60.5,3.3,-9.8,-18.1], [29.6,34.5,40,8,-14.7], [12.9,17.7,19.8,27.3,-8.8], [-14.4,-10.8,-7.9,-6.5,8.3]]
percentile_75 = [
    [92.1,94.8,59.1,48.1,33.1], [54.7,60.3,63.4,43.8,26.8], [34.3,38.7,39.9,45.3,21.5], [-0.6,2.7,3.2,3.8,15]]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) Semiannually", "(b) Quarterly", "(c) Bimonthly", "(d) Monthly"]

# Define common y-axis limits
ylim_min = 0
ylim_max = 2  # Adjust according to your data

# Plot data for each subplot
for j in range(2):
    for k in range(2):
        idx = j * 2 + k
        ax = axs[j, k]
        ax.scatter(x_values[idx], (100 + np.array(y_values[idx]))/100, color="black")
        ax.set_xlabel("Emission duration, days")
        ax.set_ylabel("Accuracy")
        ax.tick_params(axis="y")

        lns1 = ax.plot(x_values[idx], (100 + np.array(y_values[idx]))/100, linestyle="-", color="blue", label="Accuracy")

        # Add shadow region for lns1
        fill_between = ax.fill_between(
            x_values[idx],
            (100 + np.array(percentile_25[idx]))/100,
            (100 + np.array(percentile_75[idx]))/100,
            color="lightblue",
            alpha=0.3,
            label="IQR",
        )

        # Add red dashed line at y = 1.0
        ax.axhline(y=1.0, color='red', linestyle='--')

        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        ax.legend(loc="lower right")

plt.tight_layout()
plt.show()

# %%
#Repair
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]
y_values = [[72.1,75.4,30.2,14.6,5.0], [41.6,46.7,50.3,26,4.5], [23.3,26.6,29.9,35.8,5.8], [-8.5,-4.5,-2.9,-1.8,11.4]]


# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) Semiannually", "(b) Quarterly", "(c) Bimonthly", "(d) Monthly"]

# Define common y-axis limits
ylim_min = -1
ylim_max = 1  # Adjust according to your data

# Plot data for each subplot
for j in range(2):
    for k in range(2):
        idx = j * 2 + k
        ax = axs[j, k]
        ax.scatter(x_values[idx], (100 + np.array(y_values[idx]))/100-1, color="black")
        ax.set_xlabel("Emission duration, days")
        ax.set_ylabel("Emission ratio")
        ax.tick_params(axis="y")

        lns1 = ax.plot(x_values[idx], (100 + np.array(y_values[idx]))/100-1, linestyle="-", color="blue", label="Accuracy")


        # Add red dashed line at y = 1.0
        ax.axhline(y=0, color='red', linestyle='--')

        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        # ax.legend(loc="lower right")

plt.tight_layout()
plt.show()

# %%
#Repair
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]
y_values = [[17.4, 16.9, 27.6, 29, 25.9], [12.5, 12.8, 11.4, 18.0, 20.7], [10.7, 10.1, 10.1, 8.9, 15.4], [6.8, 6.6, 5.5, 5.3, 3.4]]



# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) Semiannually", "(b) Quarterly", "(c) Bimonthly", "(d) Monthly"]

# Define common y-axis limits
ylim_min = 70
ylim_max = 100  # Adjust according to your data

# Plot data for each subplot
for j in range(2):
    for k in range(2):
        idx = j * 2 + k
        ax = axs[j, k]
        ax.plot(x_values[idx], 100 - np.array(y_values[idx]), color="blue", marker='o')  # Changed to plot
        ax.set_xlabel("Survey Frequency, times/yr")
        ax.set_ylabel("Precision, %")
        ax.tick_params(axis="y")
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])
        ax.legend(loc = 'lower right')



        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        # ax.legend(loc="lower right")

plt.tight_layout()
plt.savefig(r'C:\Users\Haojun\Desktop\Uncertainty\Repair_frequency_precision.png')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Repair
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]
y_values = [[72.1,75.4,30.2,14.6,5.0], [41.6,46.7,50.3,26,4.5], [23.3,26.6,29.9,35.8,5.8], [-8.5,-4.5,-2.9,-1.8,11.4]]

# Calculate 25th and 75th percentiles
percentile_25 = [
    [55.9,60.5,3.3,-9.8,-18.1], [29.6,34.5,40,8,-14.7], [12.9,17.7,19.8,27.3,-8.8], [-14.4,-10.8,-7.9,-6.5,8.3]]
percentile_75 = [
    [92.1,94.8,59.1,48.1,33.1], [54.7,60.3,63.4,43.8,26.8], [34.3,38.7,39.9,45.3,21.5], [-0.6,2.7,3.2,3.8,15]]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) Semiannually", "(b) Quarterly", "(c) Bimonthly", "(d) Monthly"]

# Define common y-axis limits
ylim_min = 0
ylim_max = 2  # Adjust according to your data

# y-values for horizontal lines
horizontal_lines = [1.624, 1.300, 1.103, 0.819]

# Plot data for each subplot
for j in range(2):
    for k in range(2):
        idx = j * 2 + k
        ax = axs[j, k]
        ax.scatter(x_values[idx], (100 + np.array(y_values[idx]))/100, color="black")
        ax.set_xlabel("Emission duration, days")
        ax.set_ylabel("Accuracy")
        ax.tick_params(axis="y")

        lns1 = ax.plot(x_values[idx], (100 + np.array(y_values[idx]))/100, linestyle="-", color="blue", label="Accuracy")

        # Add shadow region for lns1
        fill_between = ax.fill_between(
            x_values[idx],
            (100 + np.array(percentile_25[idx]))/100,
            (100 + np.array(percentile_75[idx]))/100,
            color="lightblue",
            alpha=0.3,
            label="IQR",
        )

        # Add red dashed line at y = 1.0
        ax.axhline(y=1.0, color='red', linestyle='--')

        # Add blue dashed horizontal line at specified y-value for each subplot
        ax.axhline(y=horizontal_lines[idx], color='purple', linestyle='--')

        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        ax.legend(loc="lower right")

plt.tight_layout()
# plt.savefig(r'C:\Users\Haojun\Desktop\Uncertainty\Repair_frequency.png')
plt.show()

# %% [markdown]
# *   Non Repair

# %%
#Non_Repair
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]
y_values = [[29.3,17.6,10.5,9.2,3.6], [14.5,9.4,4.9,6.5,2.3], [9.6,6.1,3.3,2.9,3.1], [4.0,2.5,1.3,1.0,1.0]]

# Calculate 25th and 75th percentiles
percentile_25 = [
    [19.6,7.9,-6.0,-10.5,-13.5], [10.4,4.8,0.9,-4.4,-10.9], [6.6,3.5,-2.2,-0.0,-7.3], [2.6,1.2,-0.0,-0.4,-0.3]]
percentile_75 = [
    [39.4,27.4,28.5,28.9,26.0], [19.4,14.2,9.8,16.0,17.8], [12.3,9.3,3.1,5.7,13.7], [5.4,3.9,2.7,2.5,2.4]]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) Semiannually", "(b) Quarterly", "(c) Bimonthly", "(d) Monthly"]

# Define common y-axis limits
ylim_min = 0
ylim_max = 2  # Adjust according to your data

# Plot data for each subplot
for j in range(2):
    for k in range(2):
        idx = j * 2 + k
        ax = axs[j, k]
        ax.scatter(x_values[idx], (100 + np.array(y_values[idx]))/100, color="black")
        ax.set_xlabel("Emission duration, days")
        ax.set_ylabel("Accuracy")
        ax.tick_params(axis="y")

        lns1 = ax.plot(x_values[idx], (100 + np.array(y_values[idx]))/100, linestyle="-", color="blue", label="Accuracy")

        # Add shadow region for lns1
        fill_between = ax.fill_between(
            x_values[idx],
            (100 + np.array(percentile_25[idx]))/100,
            (100 + np.array(percentile_75[idx]))/100,
            color="lightblue",
            alpha=0.3,
            label="IQR",
        )

        # Add red dashed line at y = 1.0
        ax.axhline(y=1.0, color='red', linestyle='--')

        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        ax.legend(loc="lower right")

plt.tight_layout()
plt.savefig(r'C:\Users\Haojun\Desktop\Uncertainty\Non_repair_frequency.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]
y_values = [[29.3,17.6,10.5,9.2,3.6], [14.5,9.4,4.9,6.5,2.3], [9.6,6.1,3.3,2.9,3.1], [4.0,2.5,1.3,1.0,1.0]]

# Calculate 25th and 75th percentiles
percentile_25 = [
    [19.6,7.9,-6.0,-10.5,-13.5], [10.4,4.8,0.9,-4.4,-10.9], [6.6,3.5,-2.2,-0.0,-7.3], [2.6,1.2,-0.0,-0.4,-0.3]]
percentile_75 = [
    [39.4,27.4,28.5,28.9,26.0], [19.4,14.2,9.8,16.0,17.8], [12.3,9.3,3.1,5.7,13.7], [5.4,3.9,2.7,2.5,2.4]]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) Semiannually", "(b) Quarterly", "(c) Bimonthly", "(d) Monthly"]

# Define common y-axis limits
ylim_min = 0
ylim_max = 2  # Adjust according to your data

# y-values for horizontal lines
horizontal_lines = [1.322, 1.142, 1.083, 1.025]

# Plot data for each subplot
for j in range(2):
    for k in range(2):
        idx = j * 2 + k
        ax = axs[j, k]
        ax.scatter(x_values[idx], (100 + np.array(y_values[idx]))/100, color="black")
        ax.set_xlabel("Emission duration, days")
        ax.set_ylabel("Accuracy")
        ax.tick_params(axis="y")

        lns1 = ax.plot(x_values[idx], (100 + np.array(y_values[idx]))/100, linestyle="-", color="blue", label="Accuracy")

        # Add shadow region for lns1
        fill_between = ax.fill_between(
            x_values[idx],
            (100 + np.array(percentile_25[idx]))/100,
            (100 + np.array(percentile_75[idx]))/100,
            color="lightblue",
            alpha=0.3,
            label="IQR",
        )

        # Add red dashed line at y = 1.0
        ax.axhline(y=1.0, color='red', linestyle='--')

        # Add blue dashed horizontal line at specified y-value for each subplot
        ax.axhline(y=horizontal_lines[idx], color='purple', linestyle='--')

        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        ax.legend(loc="lower right")

plt.tight_layout()
# plt.savefig(r'C:\Users\Haojun\Desktop\Uncertainty\Non_repair_frequency.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]
y_values = [[29.3,17.6,10.5,9.2,3.6], [14.5,9.4,4.9,6.5,2.3], [9.6,6.1,3.3,2.9,3.1], [4.0,2.5,1.3,1.0,1.0]]


# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) Semiannually", "(b) Quarterly", "(c) Bimonthly", "(d) Monthly"]

# Define common y-axis limits
ylim_min = -1
ylim_max = 1  # Adjust according to your data

# y-values for horizontal lines
horizontal_lines = [1.322, 1.142, 1.083, 1.025]

# Plot data for each subplot
for j in range(2):
    for k in range(2):
        idx = j * 2 + k
        ax = axs[j, k]
        ax.scatter(x_values[idx], (100 + np.array(y_values[idx]))/100-1, color="black")
        ax.set_xlabel("Emission duration, days")
        ax.set_ylabel("Emission Ratio")
        ax.tick_params(axis="y")

        lns1 = ax.plot(x_values[idx], (100 + np.array(y_values[idx]))/100-1, linestyle="-", color="blue", label="Accuracy")


        # Add red dashed line at y = 1.0
        ax.axhline(y=0, color='red', linestyle='--')


        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        # ax.legend(loc="lower right")

plt.tight_layout()
# plt.savefig(r'C:\Users\Haojun\Desktop\Uncertainty\Non_repair_frequency.png')
plt.show()

# %% [markdown]
# *   Combine

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]
y_values = [[29.3,17.6,10.5,9.2,3.6], [14.5,9.4,4.9,6.5,2.3], [9.6,6.1,3.3,2.9,3.1], [4.0,2.5,1.3,1.0,1.0]]
y_values_r = [[72.1,75.4,30.2,14.6,5.0], [41.6,46.7,50.3,26,4.5], [23.3,26.6,29.9,35.8,5.8], [-8.5,-4.5,-2.9,-1.8,11.4]]


# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) Semiannually", "(b) Quarterly", "(c) Bimonthly", "(d) Monthly"]

# Define common y-axis limits
ylim_min = -1
ylim_max = 1  # Adjust according to your data

# y-values for horizontal lines
horizontal_lines = [1.322, 1.142, 1.083, 1.025]

# Plot data for each subplot
for j in range(2):
    for k in range(2):
        idx = j * 2 + k
        ax = axs[j, k]
        ax.scatter(x_values[idx], (100 + np.array(y_values[idx]))/100-1, color="black")
        ax.scatter(x_values[idx], (100 + np.array(y_values_r[idx]))/100-1, color="black")
        ax.set_xlabel("Emission duration, days")
        ax.set_ylabel("Emission Ratio")
        ax.tick_params(axis="y")

        ax.plot(x_values[idx], (100 + np.array(y_values[idx]))/100-1, linestyle="-", color="blue", label="Non-repair")
        ax.plot(x_values[idx], (100 + np.array(y_values_r[idx]))/100-1, linestyle="-", color="orange", label="Repair")


        # Add red dashed line at y = 1.0
        ax.axhline(y=0, color='red', linestyle='--')


        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        # ax.legend(loc="lower right")

plt.tight_layout()
# plt.savefig(r'C:\Users\Haojun\Desktop\Uncertainty\Non_repair_frequency.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]
y_values = [[29.3, 17.6, 10.5, 9.2, 3.6], [14.5, 9.4, 4.9, 6.5, 2.3], [9.6, 6.1, 3.3, 2.9, 3.1], [4.0, 2.5, 1.3, 1.0, 1.0]]
y_values_r = [[72.1, 75.4, 30.2, 14.6, 5.0], [41.6, 46.7, 50.3, 26, 4.5], [23.3, 26.6, 29.9, 35.8, 5.8], [-8.5, -4.5, -2.9, -1.8, 11.4]]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) Semiannually", "(b) Quarterly", "(c) Bimonthly", "(d) Monthly"]

# Define common y-axis limits
ylim_min = -1
ylim_max = 1.0  # Adjust according to your data

# x-values for vertical lines
vertical_lines = [180, 90, 60, 30]

# Plot data for each subplot
for j in range(2):
    for k in range(2):
        idx = j * 2 + k
        ax = axs[j, k]
        ax.scatter(x_values[idx], (100 + np.array(y_values[idx]))/100 - 1, color="black")
        ax.scatter(x_values[idx], (100 + np.array(y_values_r[idx]))/100 - 1, color="black")
        ax.set_xlabel("Emission duration, days")
        ax.set_ylabel("Emission ratio")
        ax.tick_params(axis="y")

        ax.plot(x_values[idx], (100 + np.array(y_values[idx]))/100 - 1, linestyle="-", color="blue", label="Non-repair")
        ax.plot(x_values[idx], (100 + np.array(y_values_r[idx]))/100 - 1, linestyle="-", color="orange", label="Repair")

        # Add red dashed line at y = 0
        ax.axhline(y=0, color='red', linestyle='--')


        # Add vertical green dashed lines
        ax.axvline(x=vertical_lines[idx], color='green', linestyle='--')

        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        ax.legend(loc="upper right")

plt.tight_layout()
# plt.savefig(r'C:\Users\Haojun\Desktop\Uncertainty\Non_repair_frequency.png')
plt.show()

# %%
#Comparison
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30, 7, 1], [360, 180, 90, 60, 30, 7, 1],  [360, 180, 90, 60, 30, 7, 1]]
y_values = [[29.3,17.6,10.5,9.2,3.6,0.4,-1.8], [14.5,9.4,4.9,6.5,2.3,-0.6,-3.7], [4.0,2.5,1.3,1.0,1.0,-0.6,-2.1]]

#Colette
x_values_2 = [[180, 30, 7, 1], [180, 30, 7, 1], [180, 30, 7, 1]]
y_values_2 = [[5, 21, 19, 11], [1, 13, 19, 12], [1, 3, 7, 6]]

# Calculate 25th and 75th percentiles
percentile_25 = [
    [19.6,7.9,-6.0,-10.5,-13.5,-15.8,-15.5], [10.4,4.8,0.9,-4.4,-10.9,-15,-15.7],  [2.6,1.2,-0.0,-0.4,-0.3,-9.5,-11.7]]
percentile_75 = [
    [39.4,27.4,28.5,28.9,26.0,24.9,19.9], [19.4,14.2,9.8,16.0,17.8,18.4,13.2],  [5.4,3.9,2.7,2.5,2.4,10.8,10.9]]

#Colette
percentile_25_2 = [
    [-2, -1, 0, -17], [-5, -9, 0, -10], [0, 2, -7, -8]]
percentile_75_2 = [
    [18, 54, 56, 55], [10, 37, 46, 44], [4, 5, 25, 24]]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) Semiannually", "(b) Quarterly", "(c) Bimonthly", "(d) Monthly"]

# Define common y-axis limits
ylim_min = 0.5
ylim_max = 1.5  # Adjust according to your data

# Plot data for each subplot
for j in range(2):
    for k in range(2):
        idx = j * 2 + k
        ax = axs[j, k]
        ax.scatter(x_values[idx], (100 + np.array(y_values[idx]))/100, color="black")
        ax.scatter(x_values_2[idx], (100 + np.array(y_values_2[idx]))/100, color="black")
        ax.set_xlabel("Emission duration, days")
        ax.set_ylabel("Accuracy")
        ax.tick_params(axis="y")

        lns1 = ax.plot(x_values[idx], (100 + np.array(y_values[idx]))/100, linestyle="-", color="blue", label="Accuracy")
        lns2 = ax.plot(x_values_2[idx], (100 + np.array(y_values_2[idx]))/100, linestyle="-", color="red", label="Accuracy")

        # Add shadow region for lns1
        fill_between = ax.fill_between(
            x_values[idx],
            (100 + np.array(percentile_25[idx]))/100,
            (100 + np.array(percentile_75[idx]))/100,
            color="lightblue",
            alpha=0.3,
            label="IQR",
        )

                # Add shadow region for lns2
        fill_between = ax.fill_between(
            x_values_2[idx],
            (100 + np.array(percentile_25_2[idx]))/100,
            (100 + np.array(percentile_75_2[idx]))/100,
            color="lightcoral",
            alpha=0.3,
            label="IQR",
        )

        # Add red dashed line at y = 1.0
        # ax.axhline(y=1.0, color='red', linestyle='--')

        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx])

        # Create legend for each subplot
        ax.legend(loc="lower right")

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-104fe49fcb90> in <cell line: 36>()
#      38         idx = j * 2 + k
#      39         ax = axs[j, k]
# ---> 40         ax.scatter(x_values[idx], (100 + np.array(y_values[idx]))/100, color="black")
#      41         ax.scatter(x_values_2[idx], (100 + np.array(y_values_2[idx]))/100, color="black")
#      42         ax.set_xlabel("Emission duration, days")
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30, 7, 1], [360, 180, 90, 60, 30, 7, 1], [360, 180, 90, 60, 30, 7, 1]]
y_values = [[29.3,17.6,10.5,9.2,3.6,0.4,-1.8], [14.5,9.4,4.9,6.5,2.3,-0.6,-3.7], [4.0,2.5,1.3,1.0,1.0,-0.6,-2.1]]

# Colette
x_values_2 = [[180, 30, 7, 1], [180, 30, 7, 1], [180, 30, 7, 1]]
y_values_2 = [[5, 21, 19, 11], [1, 13, 19, 12], [1, 3, 7, 6]]

# Calculate 25th and 75th percentiles
percentile_25 = [
    [19.6,7.9,-6.0,-10.5,-13.5,-15.8,-15.5], [10.4,4.8,0.9,-4.4,-10.9,-15,-15.7], [2.6,1.2,-0.0,-0.4,-0.3,-9.5,-11.7]]
percentile_75 = [
    [39.4,27.4,28.5,28.9,26.0,24.9,19.9], [19.4,14.2,9.8,16.0,17.8,18.4,13.2], [5.4,3.9,2.7,2.5,2.4,10.8,10.9]]

# Colette
percentile_25_2 = [
    [-2, -1, 0, -17], [-5, -9, 0, -10], [0, 2, -7, -8]]
percentile_75_2 = [
    [18, 54, 56, 55], [10, 37, 46, 44], [4, 5, 25, 24]]

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Titles for each subplot
titles = ["Semiannually", "Quarterly", "Monthly"]

# Define common y-axis limits
ylim_min = 0.5
ylim_max = 1.5  # Adjust according to your data

# Plot data for each subplot
for idx, ax in enumerate(axs):
    ax.scatter(x_values[idx], (100 + np.array(y_values[idx])) / 100, color="black")
    ax.scatter(x_values_2[idx], (100 + np.array(y_values_2[idx])) / 100, color="black")
    ax.set_xlabel("Emission duration, days")
    ax.set_ylabel("Accuracy")
    ax.tick_params(axis="y")

    ax.plot(x_values[idx], (100 + np.array(y_values[idx])) / 100, linestyle="-", color="blue", label="Accuracy")
    ax.plot(x_values_2[idx], (100 + np.array(y_values_2[idx])) / 100, linestyle="-", color="red", label="Accuracy")

    # Add shadow region for lns1
    ax.fill_between(
        x_values[idx],
        (100 + np.array(percentile_25[idx])) / 100,
        (100 + np.array(percentile_75[idx])) / 100,
        color="lightblue",
        alpha=0.3,
        label="IQR",
    )

    # Add shadow region for lns2
    ax.fill_between(
        x_values_2[idx],
        (100 + np.array(percentile_25_2[idx])) / 100,
        (100 + np.array(percentile_75_2[idx])) / 100,
        color="lightcoral",
        alpha=0.3,
        label="IQR",
    )

    # Set y-axis limits
    ax.set_ylim(ylim_min, ylim_max)
    ax.set_title(f"({chr(97 + idx)}) {titles[idx]}")

    # Create legend for each subplot
    ax.legend(loc="lower right")

plt.tight_layout()
plt.show()
