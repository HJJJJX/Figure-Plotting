# %% [markdown]
# <a href="https://colab.research.google.com/github/HJJJJX/Figure-Plotting/blob/main/Published_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

# Sample data for scatter plots
x_values = [[2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12]]
y_values = [
    [72.1, 41.6, 23.3, -8.5],
    [75.4, 46.7, 26.6, -4.5],
    [30.2, 50.3, 29.9, -2.9],
    [14.6, 26, 35.8, -1.8],
    [5.0, 4.5, 5.8, 11.4],
]

y_values_2 = [
    [29.3,14.5,9.6,4.0],
    [17.6,9.4,6.1,2.5],
    [10.5,4.9,3.3,1.3],
    [9.2,6.5,2.9,1.0],
    [3.6,2.3,3.1,1.0],
]

# Positions of the vertical dashed lines
vlines_positions = [1.8, 2.0, 4.0, 6.0, 12.0]

# Create subplots
fig, axs = plt.subplots(3, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) 360 days", "(b) 180 days", "(c) 90 days", "(d) 60 days", "(e) 30 days"]

# Define common y-axis limits (for percentage)
ylim_min = -100
ylim_max = 100  # Adjust according to your data

# Plot data for each subplot
for idx in range(5):
    row = idx // 2
    col = idx % 2
    ax = axs[row, col]

    # Convert y-values to percentages
    ax.scatter(x_values[idx], (100 + np.array(y_values[idx])) - 100, color="black")
    ax.scatter(x_values[idx], (100 + np.array(y_values_2[idx])) - 100, color="black")

    ax.set_xlabel("Survey Frequency, times/yr", fontsize=14)
    ax.set_ylabel("Quantification Error", fontsize=14)
    ax.tick_params(axis="y", labelsize=12)
    ax.tick_params(axis="x", labelsize=12)

    lns1 = ax.plot(x_values[idx], (100 + np.array(y_values[idx])) - 100, linestyle="-", color="orange", label="Repair")
    lns2 = ax.plot(x_values[idx], (100 + np.array(y_values_2[idx])) - 100, linestyle="-", color="blue", label="Non-repair")

    # Add red dashed line at y = 0
    ax.axhline(y=0, color='gray', linestyle='--')

    # Add vertical dashed line at specified x position
    ax.axvline(x=vlines_positions[idx], color='darkgreen', linestyle='--')

    # Set y-axis limits for percentage
    ax.set_ylim(ylim_min, ylim_max)
    ax.set_title(titles[idx], fontsize=14)

    # Set percentage format for y-axis
    ax.yaxis.set_major_formatter(mtick.PercentFormatter())
    # /ax.grid(True)

    # Create legend for each subplot
    ax.legend(loc="upper right", fontsize=12)

# Hide the empty subplot
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %%
#Unrepair
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

# Sample data for scatter plots
x_values = [[2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12]]
y_values = [
    [29.3,14.5,9.6,4.0],
    [17.6,9.4,6.1,2.5],
    [10.5,4.9,3.3,1.3],
    [9.2,6.5,2.9,1.0],
    [3.6,2.3,3.1,1.0],
]

y_values_1 = [
    [29.2,14.3,9.2,3.5],
    [17.6,9.1,6.1,2.3],
    [10.7,5.4,3.1,1],
    [9.5,6.3,2.9,0.8],
    [3.9,2.4,2.7,0.8],
]

y_values_2 = [
    [29,13.8,8.6,3],
    [18.1,9.1,6,1.9],
    [11.2,5.4,3,0.8],
    [8.7,5.9,2.9,0.7],
    [3.9,2.3,2.3,0.7],
]

y_values_3 = [
    [29.1,13.2,8,2.5],
    [18.3,8.7,5.6,1.6],
    [10.9,5.4,2.7,0.5],
    [8.6,5.8,2.5,0.5],
    [3.1,1.4,1.5,0.4],
]

# Positions of the vertical dashed lines
vlines_positions = [1.8, 2.0, 4.0, 6.0, 12.0]

# Create subplots
fig, axs = plt.subplots(3, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) 360 days", "(b) 180 days", "(c) 90 days", "(d) 60 days", "(e) 30 days"]

# Define common y-axis limits (for percentage)
ylim_min = -50
ylim_max = 50  # Adjust according to your data

# Plot data for each subplot
for idx in range(5):
    row = idx // 2
    col = idx % 2
    ax = axs[row, col]

    # Convert y-values to percentages
    ax.scatter(x_values[idx], (100 + np.array(y_values[idx])) - 100, color="black")
    ax.scatter(x_values[idx], (100 + np.array(y_values_1[idx])) - 100, color="orange")
    ax.scatter(x_values[idx], (100 + np.array(y_values_2[idx])) - 100, color="blue")
    ax.scatter(x_values[idx], (100 + np.array(y_values_3[idx])) - 100, color="green")

    ax.set_xlabel("Survey Frequency, times/yr", fontsize=14)
    ax.set_ylabel("Quantification Error", fontsize=14)
    ax.tick_params(axis="y", labelsize=12)
    ax.tick_params(axis="x", labelsize=12)

    lns1 = ax.plot(x_values[idx], (100 + np.array(y_values[idx])) - 100, linestyle="-", color="black", label="Repair")
    lns2 = ax.plot(x_values[idx], (100 + np.array(y_values_1[idx])) - 100, linestyle="-", color="orange", label="10% Uncertainty")
    lns3 = ax.plot(x_values[idx], (100 + np.array(y_values_2[idx])) - 100, linestyle="-", color="blue", label="20% Uncertainty")
    lns4 = ax.plot(x_values[idx], (100 + np.array(y_values_3[idx])) - 100, linestyle="-", color="green", label="30% Uncertainty")

    # Add red dashed line at y = 0
    ax.axhline(y=0, color='gray', linestyle='--')

    # Add vertical dashed line at specified x position
    # ax.axvline(x=vlines_positions[idx], color='darkgreen', linestyle='--')

    # Set y-axis limits for percentage
    ax.set_ylim(ylim_min, ylim_max)
    ax.set_title(titles[idx], fontsize=14)

    # Set percentage format for y-axis
    ax.yaxis.set_major_formatter(mtick.PercentFormatter())
    # /ax.grid(True)

    # Create legend for each subplot
    ax.legend(loc="lower right", fontsize=12)

# Hide the empty subplot
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %%
#Repair
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

# Sample data for scatter plots
x_values = [[2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12], [2, 4, 6, 12]]
y_values = [
    [72.1, 41.6, 23.3, -8.5],
    [75.4, 46.7, 26.6, -4.5],
    [30.2, 50.3, 29.9, -2.9],
    [14.6, 26, 35.8, -1.8],
    [5.0, 4.5, 5.8, 11.4],
]

y_values_1 = [
    [67.6,40.2,22.9,-8.2],
    [72.1,43.4,26,-4.4],
    [27.6,45.5,28,-2.7],
    [13.4,22.1,32.7,-1.6],
    [4.1,1.4,3.1,9.9],
]

y_values_2 = [
    [63.9,38.4,22.7,-7.9],
    [69.2,40.1,25.9,-4.5],
    [25.3,41.8,25.5,-2.7],
    [12.8,18.4,29.5,-2],
    [2.9,-1.9,-0.1,8.2],
]

y_values_3 = [
    [60.2,37.3,22.1,-7.9],
    [66.3,36.6,25.2,-4.2],
    [23.3,38.6,23.4,-2.8],
    [10.7,14.3,26.7,-2.1],
    [1.3,-5.3,-3.3,6.8],
]

# Positions of the vertical dashed lines
vlines_positions = [1.8, 2.0, 4.0, 6.0, 12.0]

# Create subplots
fig, axs = plt.subplots(3, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) 360 days", "(b) 180 days", "(c) 90 days", "(d) 60 days", "(e) 30 days"]

# Define common y-axis limits (for percentage)
ylim_min = -100
ylim_max = 100  # Adjust according to your data

# Plot data for each subplot
for idx in range(5):
    row = idx // 2
    col = idx % 2
    ax = axs[row, col]

    # Convert y-values to percentages
    ax.scatter(x_values[idx], (100 + np.array(y_values[idx])) - 100, color="black")
    ax.scatter(x_values[idx], (100 + np.array(y_values_1[idx])) - 100, color="orange")
    ax.scatter(x_values[idx], (100 + np.array(y_values_2[idx])) - 100, color="blue")
    ax.scatter(x_values[idx], (100 + np.array(y_values_3[idx])) - 100, color="green")

    ax.set_xlabel("Survey Frequency, times/yr", fontsize=14)
    ax.set_ylabel("Quantification Error", fontsize=14)
    ax.tick_params(axis="y", labelsize=12)
    ax.tick_params(axis="x", labelsize=12)

    lns1 = ax.plot(x_values[idx], (100 + np.array(y_values[idx])) - 100, linestyle="-", color="black", label="Repair")
    lns2 = ax.plot(x_values[idx], (100 + np.array(y_values_1[idx])) - 100, linestyle="-", color="orange", label="10% Uncertainty")
    lns3 = ax.plot(x_values[idx], (100 + np.array(y_values_2[idx])) - 100, linestyle="-", color="blue", label="20% Uncertainty")
    lns4 = ax.plot(x_values[idx], (100 + np.array(y_values_3[idx])) - 100, linestyle="-", color="green", label="30% Uncertainty")

    # Add red dashed line at y = 0
    ax.axhline(y=0, color='gray', linestyle='--')

    # Add vertical dashed line at specified x position
    # ax.axvline(x=vlines_positions[idx], color='darkgreen', linestyle='--')

    # Set y-axis limits for percentage
    ax.set_ylim(ylim_min, ylim_max)
    ax.set_title(titles[idx], fontsize=14)

    # Set percentage format for y-axis
    ax.yaxis.set_major_formatter(mtick.PercentFormatter())
    # /ax.grid(True)

    # Create legend for each subplot
    ax.legend(loc="lower right", fontsize=12)

# Hide the empty subplot
fig.delaxes(axs[2, 1])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as mtick

# Sample data for scatter plots
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]
y_values = [[29.3, 17.6, 10.5, 9.2, 3.6], [14.5, 9.4, 4.9, 6.5, 2.3], [9.6, 6.1, 3.3, 2.9, 3.1], [4.0, 2.5, 1.3, 1.0, 1.0]]
y_values_r = [[72.1, 75.4, 30.2, 14.6, 5.0], [41.6, 46.7, 50.3, 26, 4.5], [23.3, 26.6, 29.9, 35.8, 5.8], [-8.5, -4.5, -2.9, -1.8, 11.4]]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for each subplot
titles = ["(a) Semiannually", "(b) Quarterly", "(c) Bimonthly", "(d) Monthly"]

# Define common y-axis limits for percentage
ylim_min = -1
ylim_max = 1.0

# x-values for vertical lines
vertical_lines = [180, 90, 60, 30]

# Plot data for each subplot
for j in range(2):
    for k in range(2):
        idx = j * 2 + k
        ax = axs[j, k]

        # Convert y-values to percentage deviation
        ax.scatter(x_values[idx], (100 + np.array(y_values[idx])) / 100 - 1, color="black")
        ax.scatter(x_values[idx], (100 + np.array(y_values_r[idx])) / 100 - 1, color="black")

        ax.set_xlabel("Emission Duration, days", fontsize=14)
        ax.set_ylabel("Quantification Error", fontsize=14)
        ax.tick_params(axis="y", labelsize=12)
        ax.tick_params(axis="x", labelsize=12)

        ax.plot(x_values[idx], (100 + np.array(y_values[idx])) / 100 - 1, linestyle="-", color="blue", label="Non-repair")
        ax.plot(x_values[idx], (100 + np.array(y_values_r[idx])) / 100 - 1, linestyle="-", color="orange", label="Repair")

        # Add red dashed line at y = 0
        ax.axhline(y=0, color='gray', linestyle='--')

        # Add vertical green dashed lines
        ax.axvline(x=vertical_lines[idx], color='darkgreen', linestyle='--')

        # Set y-axis limits
        ax.set_ylim(ylim_min, ylim_max)
        ax.set_title(titles[idx], fontsize=14)

        # Set y-axis to percentage format
        ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1, decimals=0))

        # Manually reduce the x-axis interval
        ax.set_xticks(np.arange(00, 361, 50))  # Ticks every 30 days

        # Create legend for each subplot
        ax.legend(loc="lower right", fontsize=12)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]

# Calculate 25th and 75th percentiles
percentile_25 = [
    [19.6,7.9,-6.0,-10.5,-13.5], [10.4,4.8,0.9,-4.4,-10.9], [6.6,3.5,-2.2,-0.0,-7.3], [2.6,1.2,-0.0,-0.4,-0.3]]
percentile_75 = [
    [39.4,27.4,28.5,28.9,26.0], [19.4,14.2,9.8,16.0,17.8], [12.3,9.3,3.1,5.7,13.7], [5.4,3.9,2.7,2.5,2.4]]

# Convert to numpy arrays for easier manipulation
percentile_25 = np.array(percentile_25)
percentile_75 = np.array(percentile_75)

# Calculate the interquartile range (IQR)
difference = (100 + (percentile_75 - percentile_25)) / 100 - 1

# Plotting
plt.figure(figsize=(10, 6))

# Color-blind friendly colors
colors = ['#0072B2', '#D55E00', '#009E73', '#CC79A7']  # Blue, Orange, Green, Purple

labels = ["Semiannually", "Quarterly", "Bimonthly", "Monthly"]
for i in range(difference.shape[0]):
    plt.plot(x_values[i], difference[i], marker='o', color=colors[i], label=labels[i])

# Customize tick labels
plt.xticks(fontsize=14)  # Change x-axis tick label font size and rotate 45 degrees
plt.yticks(fontsize=14)  # Change y-axis tick label font size

plt.xlabel('Emission Duration, days', fontsize=14)
plt.ylabel('Interquartile Range', fontsize=14)
plt.ylim(0, 0.6)  # Set the y-axis limits
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data
x_values = np.array([[360, 180, 90, 60, 30]] * 4)

# Calculate 25th and 75th percentiles
percentile_25 = np.array([
    [19.6, 7.9, -6.0, -10.5, -13.5],
    [10.4, 4.8, 0.9, -4.4, -10.9],
    [6.6, 3.5, -2.2, -0.0, -7.3],
    [2.6, 1.2, -0.0, -0.4, -0.3]
])

percentile_75 = np.array([
    [39.4, 27.4, 28.5, 28.9, 26.0],
    [19.4, 14.2, 9.8, 16.0, 17.8],
    [12.3, 9.3, 9.1, 5.7, 13.7],
    [5.4, 3.9, 2.7, 2.5, 2.4]
])

# Calculate the interquartile range (IQR)
difference = (100 + (percentile_75 - percentile_25)) / 100 - 1

# IAD1 data and conversion
IAD1 = np.array([
    [20.6, 19.5, 34.6, 40.7, 40.5],
    [9.6, 9.4, 9.7, 20.7, 28.7],
    [6.4, 6.1, 11.3, 6.2, 21.4],
    [3.5, 3.3, 3.5, 3.7, 3.8]
])
D1 = (100 + IAD1) / 100 - 1

IAD2 = np.array([
    [21.8,20.4,35.2,41.3,40.8],
    [10.3,10.8,10.9,21.8,29.5],
    [7.4,6.9,11.1,8.1,21.9],
    [4.4,4.3,4.7,4.9,5.6]
])
D2 = (100 + IAD2) / 100 - 1

IAD3 = np.array([
    [23.2,22,36.8,42,40.8],
    [11.5,12,12.5,22.5,29.6],
    [8.8,8.2,11.9,9.6,22.4],
    [5.5,5.4,6,6.1,7.2]
])
D3 = (100 + IAD3) / 100 - 1

# Plotting
plt.figure(figsize=(10, 6))

# Color-blind friendly colors
colors = ['#0072B2', '#D55E00', '#009E73', '#CC79A7']  # Blue, Orange, Green, Purple

labels = ["Semiannually", "Quarterly", "Bimonthly", "Monthly"]
for i in range(difference.shape[0]):
    plt.plot(x_values[i], difference[i], marker='o', color=colors[i], label=labels[i])
    plt.plot(x_values[i], D1[i], marker='x', linestyle='--', color=colors[i])
    plt.plot(x_values[i], D2[i], marker='*', linestyle='--', color=colors[i])
    plt.plot(x_values[i], D3[i], marker='+', linestyle='--', color=colors[i])

# Customize tick labels
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.xlabel('Emission Duration, days', fontsize=14)
plt.ylabel('Interquartile Range', fontsize=14)
plt.ylim(0, 0.6)  # Set the y-axis limits
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data
x_values = [[360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30], [360, 180, 90, 60, 30]]

# Calculate 25th and 75th percentiles
percentile_25 = [
    [55.9,60.5,3.3,-9.8,-18.1], [29.6,34.5,40,8,-14.7], [12.9,17.7,19.8,27.3,-8.8], [-14.4,-10.8,-7.9,-6.5,8.3]]
percentile_75 = [
    [92.1,94.8,59.1,48.1,33.1], [54.7,60.3,63.4,43.8,26.8], [34.3,38.7,39.9,45.3,21.5], [-0.6,2.7,3.2,3.8,15]]

# Convert to numpy arrays for easier manipulation
percentile_25 = np.array(percentile_25)
percentile_75 = np.array(percentile_75)

# Calculate the interquartile range (IQR)
difference = (100 + (percentile_75 - percentile_25)) / 100 - 1

# Plotting
plt.figure(figsize=(10, 6))

# Color-blind friendly colors
colors = ['#0072B2', '#D55E00', '#009E73', '#CC79A7']  # Blue, Orange, Green, Purple

labels = ["Semiannually", "Quarterly", "Bimonthly", "Monthly"]
for i in range(difference.shape[0]):
    plt.plot(x_values[i], difference[i], marker='o', color=colors[i], label=labels[i])

# Customize tick labels
plt.xticks(fontsize=14)  # Change x-axis tick label font size and rotate 45 degrees
plt.yticks(fontsize=14)  # Change y-axis tick label font size

plt.xlabel('Emission Duration, days', fontsize=14)
plt.ylabel('Interquartile Range', fontsize=14)
plt.ylim(0, 0.6)  # Set the y-axis limits
plt.legend(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data
x_values = np.array([[360, 180, 90, 60, 30]] * 4)

# Convert percentiles to numpy arrays
percentile_25 = np.array([
    [55.9, 60.5, 3.3, -9.8, -18.1],
    [29.6, 34.5, 40, 8, -14.7],
    [12.9, 17.7, 19.8, 27.3, -8.8],
    [-14.4, -10.8, -7.9, -6.5, 8.3]
])
percentile_75 = np.array([
    [92.1, 94.8, 59.1, 48.1, 33.1],
    [54.7, 60.3, 63.4, 43.8, 26.8],
    [34.3, 38.7, 39.9, 45.3, 21.5],
    [-0.6, 2.7, 3.2, 3.8, 15]
])

# Calculate the interquartile range (IQR)
difference = (100 + (percentile_75 - percentile_25)) / 100 - 1

# IAD1, IAD2, and IAD3 data
IAD1 = np.array([
    [36.5, 34.1, 54.3, 57.1, 52.9],
    [24.3, 26.5, 22.6, 34.6, 40.1],
    [21.9, 20.7, 19.4, 17.3, 29.5],
    [14, 14.2, 10.9, 10.2, 7.5]
])
D1 = (100 + IAD1) / 100 - 1

IAD2 = np.array([
    [37.3, 36.7, 53.7, 54.9, 51.9],
    [25.7, 26.5, 23.2, 35.1, 39.3],
    [22.5, 21.9, 19.3, 17.2, 28.5],
    [14.5, 15.4, 11.7, 11.3, 8.8]
])
D2 = (100 + IAD2) / 100 - 1

IAD3 = np.array([
    [39.9, 39.1, 54.4, 53.7, 51.9],
    [27.7, 27.2, 24.7, 34.3, 38.9],
    [24.9, 24.1, 20.4, 18.3, 28.3],
    [15.8, 17.1, 13.1, 12.8, 10.9]
])
D3 = (100 + IAD3) / 100 - 1

# Plotting
plt.figure(figsize=(10, 6))

# Color-blind friendly colors
colors = ['#0072B2', '#D55E00', '#009E73', '#CC79A7']  # Blue, Orange, Green, Purple

labels = ["Semiannually", "Quarterly", "Bimonthly", "Monthly"]
for i in range(difference.shape[0]):
    plt.plot(x_values[i], difference[i], marker='o', color=colors[i], label=f'{labels[i]} - IQR')
    plt.plot(x_values[i] + 2, D1[i], marker='x', linestyle='--', color=colors[i], alpha=0.8)
    plt.plot(x_values[i] - 2, D2[i], marker='*', linestyle='--', color=colors[i], alpha=0.8)
    plt.plot(x_values[i], D3[i], marker='+', linestyle='--', color=colors[i], alpha=0.8)

# Customize tick labels
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.xlabel('Emission Duration, days', fontsize=14)
plt.ylabel('Interquartile Range', fontsize=14)
plt.ylim(0, 0.6)  # Set the y-axis limits

# Combine and simplify legend
handles, labels = plt.gca().get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
plt.legend(unique_labels.values(), unique_labels.keys(), fontsize=12, loc='upper right', ncol=2)

plt.show()
